# %% [markdown]
# <a href="https://colab.research.google.com/github/Coresight-Adithya/Automated-Projections/blob/main/Home%20Furniture%20US/Sarima%20model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sqlalchemy
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (1.4.37)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (4.11.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (4.1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pmdarima
#   Downloading pmdarima-1.8.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.5 MB/s
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.30)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.21.6)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading statsmodels-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 28.7 MB/s
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.9)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.5 statsmodels-0.13.2

# %%
from sqlalchemy import create_engine
from urllib.parse import quote
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose
from pandas.tseries.offsets import MonthEnd
import pandas as pd
import numpy as np
from datetime import datetime

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install pymysql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 998 kB/s
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %%
# Data from DWH
db = 'mysql+pymysql://warehouse_user:%s@partner1.coresight.com:3306/warehouse_db?charset=utf8mb4' %quote('DW@core.local')
cnx = create_engine(db).raw_connection()

dftmp = pd.read_sql_query("""
select mth, amt from dwh_uscensusretailtrade where catcode='442'
""", con=cnx)

dftmp['ds'] = pd.to_datetime(dftmp['mth'], format='%Y-%m') + MonthEnd(1)
df = dftmp[['ds', 'amt']]
df.columns = ['ds', 'y']

cnx.close()

# %%
df.to_excel('Data MarketSize - USCensus.xlsx')

# %%
df = df[['ds', 'y']][df['ds'] > '2010-01-01']

# %%
df = df.set_index('ds')
df.index.freq = 'M'

# %%
df.plot(figsize=(12,8))

# %%
res = seasonal_decompose(df, model='additive')

# %%
res.plot();

# %%
res.seasonal["2020":"2021"].plot(figsize=(20,8));

# %%
auto_arima(y=df, seasonal=True, m=12, trace=True).summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=1.32 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2454.461, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=2400.798, Time=0.35 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=2419.152, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2452.696, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=2451.357, Time=0.03 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=2381.862, Time=0.93 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=2365.472, Time=1.93 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=2364.665, Time=0.83 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=2422.669, Time=0.29 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=2364.870, Time=2.13 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=2409.734, Time=0.73 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=3.24 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=2362.938, Time=0.59 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=2421.649, Time=0.20 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=2398.800, Time=0.23 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=2363.600, Time=1.73 sec
#  ARIMA(0,1,0)(1,0,2)[12] intercept   : AIC=2362.945, Time=1.54 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=2407.949, Time=0.61 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=2380.185, Time=0.70 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=2.37 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=2363.806, Time=1.04 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=2355.794, Time=1.08 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=1.54 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=1.55 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=2359.059, Time=2.32 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=2.45 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=2.14 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=inf, Time=2.01 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=4.64 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=2350.248, Time=1.27 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=2398.902, Time=1.14 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=2376.944, Time=0.79 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=2351.884, Time=2.96 sec
#  ARIMA(2,1,1)(1,0,2)[12] intercept   : AIC=2353.465, Time=2.99 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=2427.856, Time=0.13 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=2388.151, Time=1.64 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=2361.883, Time=1.85 sec
#  ARIMA(2,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=2.32 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=2346.373, Time=1.13 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=2399.067, Time=0.37 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=2375.904, Time=0.69 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=2346.342, Time=2.52 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=2360.796, Time=1.28 sec
#  ARIMA(2,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=3.59 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=2357.544, Time=2.18 sec
#  ARIMA(3,1,0)(2,0,1)[12] intercept   : AIC=2352.189, Time=2.86 sec
#  ARIMA(3,1,1)(2,0,1)[12] intercept   : AIC=2342.650, Time=3.59 sec
#  ARIMA(3,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.48 sec
#  ARIMA(3,1,1)(2,0,0)[12] intercept   : AIC=inf, Time=2.76 sec
#  ARIMA(3,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=3.62 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=1.25 sec
#  ARIMA(3,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=3.26 sec
#  ARIMA(4,1,1)(2,0,1)[12] intercept   : AIC=2342.958, Time=4.10 sec
#  ARIMA(3,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=3.06 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=2349.776, Time=3.52 sec
#  ARIMA(4,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=3.60 sec
#  ARIMA(4,1,2)(2,0,1)[12] intercept   : AIC=2378.630, Time=4.31 sec
#  ARIMA(3,1,1)(2,0,1)[12]             : AIC=2339.911, Time=2.81 sec
#  ARIMA(3,1,1)(1,0,1)[12]             : AIC=inf, Time=1.24 sec
#  ARIMA(3,1,1)(2,0,0)[12]             : AIC=inf, Time=2.36 sec
#  ARIMA(3,1,1)(2,0,2)[12]             : AIC=inf, Time=3.19 sec
#  ARIMA(3,1,1)(1,0,0)[12]             : AIC=inf, Time=0.89 sec
#  ARIMA(3,1,1)(1,0,2)[12]             : AIC=inf, Time=3.16 sec
#  ARIMA(2,1,1)(2,0,1)[12]             : AIC=inf, Time=2.83 sec
#  ARIMA(3,1,0)(2,0,1)[12]             : AIC=2346.090, Time=2.59 sec
#  ARIMA(4,1,1)(2,0,1)[12]             : AIC=inf, Time=3.28 sec
#  ARIMA(3,1,2)(2,0,1)[12]             : AIC=2345.368, Time=3.37 sec
#  ARIMA(2,1,0)(2,0,1)[12]             : AIC=2344.090, Time=2.51 sec
#  ARIMA(2,1,2)(2,0,1)[12]             : AIC=inf, Time=2.85 sec
#  ARIMA(4,1,0)(2,0,1)[12]             : AIC=2341.256, Time=3.70 sec
#  ARIMA(4,1,2)(2,0,1)[12]             : AIC=2367.439, Time=3.85 sec
#
# Best model:  ARIMA(3,1,1)(2,0,1)[12]
# Total fit time: 142.236 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  148
# Model:             SARIMAX(3, 1, 1)x(2, 0, 1, 12)   Log Likelihood               -1161.955
# Date:                            Thu, 23 Jun 2022   AIC                           2339.911
# Time:                                    12:10:53   BIC                           2363.834
# Sample:                                         0   HQIC                          2349.631
#                                             - 148
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8952      0.091      9.841      0.000       0.717       1.073
# ar.L2         -0.4103      0.075     -5.489      0.000      -0.557      -0.264
# ar.L3          0.2086      0.098      2.120      0.034       0.016       0.401
# ma.L1         -0.9224      0.071    -12.936      0.000      -1.062      -0.783
# ar.S.L12       0.9765      0.117      8.320      0.000       0.746       1.207
# ar.S.L24       0.0088      0.100      0.088      0.930      -0.188       0.206
# ma.S.L12      -0.8249      0.134     -6.176      0.000      -1.087      -0.563
# sigma2      3.231e+05   2.11e+04     15.312      0.000    2.82e+05    3.64e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):               768.90
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.25   Skew:                            -1.73
# Prob(H) (two-sided):                  0.01   Kurtosis:                        13.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
sxorder = (2,1,0)
sxsorder = (2,0,1,12)

# %%
def testmodel(train, test):
    print('train end: ', train.index[-1])
    
    print('\n---------\n')

    model = SARIMAX(endog=train, order=sxorder, seasonal_order=sxsorder).fit(disp=0)

    test['ypred'] = model.predict(start=test.index[0], end=test.index[-1])

    mape = round(np.mean(np.abs((test['y'] - test['ypred'])/test['y'])),3)
    accuracy = round((1-mape)*100,1)
    print('Accuracy: ', accuracy)

    print('\n---------\n')

    dffcast = model.get_forecast(steps=24).summary_frame()
    dffcast['bounds'] = round((pd.to_numeric(dffcast['mean_ci_upper'])-pd.to_numeric(dffcast['mean_ci_lower']))/pd.to_numeric(dffcast['mean'])*100)
    print(dffcast[['mean_ci_lower', 'mean', 'mean_ci_upper', 'bounds']])
    
    print('\n---------\n')
    
    test['mape'] = (1-round(abs(test['y'] - test['ypred'])/test['y'],6))*100
    test[['y', 'ypred', 'mape']]
    print(test[['y', 'ypred', 'mape']])

# %%
df[:-48]
# Out:
#                   y
# ds
# 2010-01-31   6324.0
# 2010-02-28   6468.0
# 2010-03-31   7271.0
# 2010-04-30   6729.0
# 2010-05-31   6932.0
# ...             ...
# 2017-12-31  11422.0
# 2018-01-31   8864.0
# 2018-02-28   8686.0
# 2018-03-31  10165.0
# 2018-04-30   9347.0
#
# [100 rows x 1 columns]

# %%
testmodel(df[:-48], df[-48:])
# Out:
# train end:  2018-04-30 00:00:00
#
# ---------
#
# Accuracy:  90.8
#
# ---------
#
# y           mean_ci_lower          mean  mean_ci_upper  bounds
# 2018-05-31    9457.430587   9952.942692   10448.454798    10.0
# 2018-06-30    9389.135485   9930.013482   10470.891480    11.0
# 2018-07-31    9294.164761   9863.884779   10433.604797    12.0
# 2018-08-31    9751.762137  10400.220193   11048.678249    12.0
# 2018-09-30    9385.128600  10080.486987   10775.845374    14.0
# 2018-10-31    9339.210792  10072.472012   10805.733231    15.0
# 2018-11-30   10230.289787  11010.325841   11790.361894    14.0
# 2018-12-31   10841.974232  11662.478164   12482.982096    14.0
# 2019-01-31    8498.331636   9355.466047   10212.600458    18.0
# 2019-02-28    8308.054040   9202.643292   10097.232543    19.0
# 2019-03-31    9600.128337  10530.104625   11460.080912    18.0
# 2019-04-30    8829.000379   9792.517380   10756.034381    20.0
# 2019-05-31    9146.057299  10339.525477   11532.993655    23.0
# 2019-06-30    9042.704758  10318.452292   11594.199826    25.0
# 2019-07-31    8915.533361  10257.307348   11599.081334    26.0
# 2019-08-31    9296.867429  10741.360842   12185.854254    27.0
# 2019-09-30    8930.889229  10453.570327   11976.251426    29.0
# 2019-10-31    8847.164915  10439.210966   12031.257017    31.0
# 2019-11-30    9620.975082  11288.266665   12955.558248    30.0
# 2019-12-31   10145.610696  11881.938072   13618.265447    29.0
# 2020-01-31    7997.577998   9798.683486   11599.788974    37.0
# 2020-02-29    7785.444898   9651.023686   11516.602474    39.0
# 2020-03-31    8930.323817  10857.754026   12785.184234    36.0
# 2020-04-30    8204.441559  10191.334679   12178.227799    39.0
#
# ---------
#
#                   y         ypred     mape
# ds
# 2018-05-31  10098.0   9952.942692  98.5635
# 2018-06-30   9905.0   9930.013482  99.7475
# 2018-07-31   9904.0   9863.884779  99.5950
# 2018-08-31  10393.0  10400.220193  99.9305
# 2018-09-30   9756.0  10080.486987  96.6740
# 2018-10-31   9965.0  10072.472012  98.9215
# 2018-11-30  10789.0  11010.325841  97.9486
# 2018-12-31  11154.0  11662.478164  95.4413
# 2019-01-31   8846.0   9355.466047  94.2407
# 2019-02-28   8659.0   9202.643292  93.7216
# 2019-03-31  10054.0  10530.104625  95.2645
# 2019-04-30   9617.0   9792.517380  98.1749
# 2019-05-31  10334.0  10339.525477  99.9465
# 2019-06-30   9785.0  10318.452292  94.5483
# 2019-07-31  10210.0  10257.307348  99.5367
# 2019-08-31  10631.0  10741.360842  98.9619
# 2019-09-30  10109.0  10453.570327  96.5914
# 2019-10-31  10248.0  10439.210966  98.1342
# 2019-11-30  11009.0  11288.266665  97.4633
# 2019-12-31  11148.0  11881.938072  93.4164
# 2020-01-31   9386.0   9798.683486  95.6032
# 2020-02-29   9344.0   9651.023686  96.7142
# 2020-03-31   8037.0  10857.754026  64.9029
# 2020-04-30   3852.0  10191.334679 -64.5726
# 2020-05-31   7145.0  10685.268336  50.4511
# 2020-06-30   9712.0  10666.432541  90.1726
# 2020-07-31  10318.0  10612.844964  97.1424
# 2020-08-31  10790.0  11050.302580  97.5876
# 2020-09-30  10844.0  10789.354892  99.4961
# 2020-10-31  10859.0  10783.475393  99.3045
# 2020-11-30  10943.0  11548.314613  94.4685
# 2020-12-31  11793.0  12079.873771  97.5674
# 2021-01-31  10432.0  10197.994520  97.7568
# 2021-02-28   9916.0  10074.147523  98.4051
# 2021-03-31  12401.0  11156.311936  89.9630
# 2021-04-30  11951.0  10554.676288  88.3163
# 2021-05-31  11925.0  11000.887491  92.2506
# 2021-06-30  11730.0  10983.679923  93.6375
# 2021-07-31  12027.0  10933.665580  90.9093
# 2021-08-31  12091.0  11328.491549  93.6936
# 2021-09-30  11974.0  11093.823031  92.6493
# 2021-10-31  12040.0  11081.511248  92.0391
# 2021-11-30  12795.0  11774.266820  92.0224
# 2021-12-31  12678.0  12258.923469  96.6945
# 2022-01-31  10423.0  10559.613365  98.6893
# 2022-02-28  10699.0  10438.361602  97.5639
# 2022-03-31  12566.0  11423.359992  90.9069
# 2022-04-30  12215.0  10879.731105  89.0686

# %%
model = SARIMAX(endog=df, order=sxorder, seasonal_order=sxsorder).fit(disp=0)
pred = model.get_forecast(steps=51).summary_frame()

# %%
dffin = pd.DataFrame(index=pd.date_range(df.index[0], pred.index[-1], freq='M'))

# %%
dffin['y'] = df['y']
dffin['ypred'] = pred['mean']

# %%
pred[['mean_ci_lower', 'mean', 'mean_ci_upper']].plot()

# %%
dffin.plot(figsize=(12,8))

# %%
pred
# Out:
# y                   mean      mean_se  mean_ci_lower  mean_ci_upper
# 2022-03-31  28298.310030   752.168592   26824.086679   29772.533381
# 2022-04-30  26988.427903   873.917302   25275.581466   28701.274340
# 2022-05-31  27140.333086   965.712108   25247.572136   29033.094037
# 2022-06-30  27284.805536  1129.062458   25071.883782   29497.727289
# 2022-07-31  27189.046484  1206.655671   24824.044827   29554.048142
# 2022-08-31  27483.304942  1308.597458   24918.501053   30048.108831
# 2022-09-30  27103.003230  1400.118136   24358.822110   29847.184350
# 2022-10-31  27957.907249  1476.797700   25063.436943   30852.377554
# 2022-11-30  27155.236840  1559.745124   24098.192572   30212.281107
# 2022-12-31  29147.444653  1632.639915   25947.529220   32347.360086
# 2023-01-31  27706.823630  1703.809483   24367.418406   31046.228854
# 2023-02-28  26523.528284  1773.213539   23048.093611   29998.962957
# 2023-03-31  28666.628967  1892.178109   24958.028022   32375.229913
# 2023-04-30  27791.063345  1982.972714   23904.508243   31677.618446
# 2023-05-31  27894.815539  2067.073593   23843.425744   31946.205334
# 2023-06-30  27918.343092  2159.144769   23686.497109   32150.189076
# 2023-07-31  27954.682268  2237.726266   23568.819379   32340.545157
# 2023-08-31  28146.296353  2318.237386   23602.634568   32689.958138
# 2023-09-30  27821.115924  2395.658730   23125.711094   32516.520753
# 2023-10-31  28609.715824  2469.052418   23770.462010   33448.969639
# 2023-11-30  27859.684742  2542.056266   22877.346014   32842.023470
# 2023-12-31  29679.484906  2612.019705   24560.020357   34798.949455
# 2024-01-31  28369.546370  2680.388432   23116.081579   33623.011162
# 2024-02-29  27297.266846  2747.261854   21912.732556   32681.801136
# 2024-03-31  29240.975167  2850.363295   23654.365766   34827.584567
# 2024-04-30  28444.973507  2934.079678   22694.283010   34195.664003
# 2024-05-31  28540.576629  3013.745561   22633.743871   34447.409386
# 2024-06-30  28561.812330  3099.715209   22486.482158   34637.142503
# 2024-07-31  28593.974230  3175.940254   22369.245715   34818.702746
# 2024-08-31  28768.128484  3253.993229   22390.418949   35145.838019
# 2024-09-30  28473.428831  3329.858552   21947.025996   34999.831666
# 2024-10-31  29187.162540  3402.802840   22517.791528   35856.533552
# 2024-11-30  28508.525292  3475.582613   21696.508544   35320.542039
# 2024-12-31  30155.218359  3546.061218   23205.066085   37105.370633
# 2025-01-31  28969.879253  3615.362333   21883.899289   36055.859217
# 2025-02-28  27999.480571  3683.519205   20779.915593   35219.045549
# 2025-03-31  29758.439885  3779.774428   22350.218136   37166.661633
# 2025-04-30  29038.120198  3861.421171   21469.873775   36606.366622
# 2025-05-31  29124.615171  3940.014737   21402.328188   36846.902153
# 2025-06-30  29143.841870  4023.660232   21257.612728   37030.071011
# 2025-07-31  29172.947553  4099.713535   21137.656678   37208.238428
# 2025-08-31  29330.544850  4177.268909   21143.248235   37517.841466
# 2025-09-30  29063.858935  4253.123574   20727.889907   37399.827963
# 2025-10-31  29709.754758  4326.656610   21229.663630   38189.845887
# 2025-11-30  29095.617652  4400.066712   20471.645367   37719.589937
# 2025-12-31  30585.804607  4471.615753   21821.598778   39350.010436
# 2026-01-31  29513.122933  4542.197764   20610.578905   38415.666962
# 2026-02-28  28634.954555  4611.830001   19595.933849   37673.975260
# 2026-03-31  30226.736703  4704.097177   21006.875656   39446.597750
# 2026-04-30  29574.878356  4784.764117   20196.913013   38952.843699
# 2026-05-31  29653.152749  4862.986242   20121.874857   39184.430642

# %%
pred = pred[['mean', 'mean_ci_lower', 'mean_ci_upper']]
pred.columns = ['Projection', 'Lower Bound', 'Upper Bound']
pred.to_excel('Furniture Projected MarketSize - USCensus.xlsx')
